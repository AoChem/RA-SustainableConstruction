# %%
'''
This script is used for interacting with OpenLCA.
Codes are developed by Ao Chen @ETH-ML.
Connect to IPC server in OpenLCA software before running. (Port: 8080)
TODO: if you're running this script in your machine for the first time, run `product_system_reader.ipynb` first!
Search for TODO in the notebook to see how to run this notebook as needed. 
'''

from notebook.services.config import ConfigManager
cm = ConfigManager()
cm.update('notebook', {'highlight_selected_word': {
    'highlight_across_all_cells': True,
    'only_cells_in_scroll': False,
    'delay': 500,
    'code_cells_only': True,
}})

import os
import csv
import copy
import json
import olca
import uuid
import math
import logging
import traceback
import numpy as np
import pandas as pd
from datetime import datetime, date

from matplotlib import pyplot as plt
import matplotlib.mlab as mlab
from matplotlib import rcParams
import matplotlib.patches as mpatches
import seaborn as sns

params = {'mathtext.default': 'regular' }

client = olca.Client(8080)
client

# %%
def get_all_process(client):
    # Get all process dataset in dataframe
    Process_descriptor = client.get_descriptors(olca.Process)
    Process_list = []
    ID_list = []
    Location_list = []

    for process in Process_descriptor:
        Process_list.append(process.name)
        ID_list.append(process.id)
        Location_list.append(process.location)
    Processes_df = pd.DataFrame(list(zip(Process_list,
                                    ID_list, Location_list)),
                                columns=['name', 'id', 'location'])
    return Processes_df

# %%
Processes_df = get_all_process(client)

# %%
Processes_df.head()
# Out:
#                                                 name  \
# 0  heat production, heavy fuel oil, at industrial...
# 1  containerboard production, fluting medium, rec...
# 2  market for wood chips, dry, measured as dry ma...
# 3  treatment of waste glass, unsanitary landfill,...
# 4  heat and power co-generation, natural gas, con...
#
#                                      id location
# 0  4f582f90-d0ae-3552-be43-70c730e82af0      RoW
# 1  fdffa34a-17fa-3676-9941-0a8a2bc5f5ac      RoW
# 2  35ca5293-f067-326c-ae45-920013c734c7      RER
# 3  ab082ee7-7469-3a1f-8e8f-f71328b9e842      GLO
# 4  3c7c0ba3-acd4-3e19-be88-8fff9dc87788       SE

# %%
class LCA_Calculation():
    def __init__(self, Processes_df, Impact_method, Result_path, Calc_range_start=0, Calc_range_end=0, Excel_path='', Process_list_target=''):
        self.Processes_df = Processes_df
        self.Impact_method = Impact_method
        self.Result_path = Result_path
        self.Excel_path = Excel_path
        self.Process_list_target = Process_list_target
        self.Calc_range_start = Calc_range_start
        self.Calc_range_end = Calc_range_end

        if not os.path.exists(self.Result_path):
            os.makedirs(self.Result_path)
    
    def create_calc_product_system(self, search_process_list, Created_PS_refProcess, cached_path):
        product_system_ids = []
        product_system_names = []
        product_system_locations = []
        
        orig_json_len = len(Created_PS_refProcess)
        calc_error_csv = self.Result_path+"process_calc_error"

        for j in range(len(search_process_list)):
        # for j in range(2): # for test
            # Create product systems for selected processes
            search_process_ID = search_process_list[j]['id']
            search_process_name = search_process_list[j]['name']
            search_process_location = search_process_list[j]['location']
            if search_process_ID not in Created_PS_refProcess.keys():
                print('Creating product system of: '+search_process_name+' | '+search_process_location)
                try:
                    product_system = client.create_product_system(search_process_ID, default_providers='prefer', preferred_type='UNIT_PROCESS') #TODO: preferred_type can be changed to "SYSTEM_PROCESS" if needed
                except Exception as e:
                    print('Failed to create product system of '+search_process_ID)
                    logging.error(traceback.format_exc())
                product_system_ids.append(product_system.id)
                product_system_names.append(search_process_name)
                product_system_locations.append(search_process_location)
                Created_PS_refProcess[search_process_ID] = {'Process': [search_process_name, search_process_location, search_process_ID], 'Product_system': product_system.id}
            else:
                print('Product system of '+'"'+Created_PS_refProcess[search_process_ID]['Process'][0]+' | '+Created_PS_refProcess[search_process_ID]['Process'][1]+'"'+' has been created before.')
                print('ID: '+Created_PS_refProcess[search_process_ID]['Product_system'])
                product_system_ids.append(Created_PS_refProcess[search_process_ID]['Product_system'])
                product_system_names.append(Created_PS_refProcess[search_process_ID]['Process'][0])
                product_system_locations.append(Created_PS_refProcess[search_process_ID]['Process'][1])

        product_system_df = pd.DataFrame(list(zip(product_system_names, product_system_ids, product_system_locations)), 
                                columns=['name', 'id', 'location'])
        
        if len(Created_PS_refProcess) > orig_json_len:
            Created_PS_refProcess_file = open("Created_PS_refProcess.json", "w")
            json.dump(Created_PS_refProcess, Created_PS_refProcess_file)
            # Created_PS_refProcess_file.close()

        setup = olca.CalculationSetup()
        setup.calculation_type = olca.CalculationType.SIMPLE_CALCULATION # TODO: Can choose SIMPLE_CALCULATION, CONTRIBUTION_ANALYSIS, UPSTREAM_ANALYSIS, REGIONALIZED_CALCULATION, MONTE_CARLO_SIMULATION
        setup.impact_method = client.find(olca.ImpactMethod, self.Impact_method)
        setup.amount = 1.0
        # amount is the amount of the functional unit (fu) of the system that should be used in the calculation; unit, flow property, etc. of the fu
        # can be also defined; by default openLCA will take the settings of the reference flow of the product system

        calc_result = {}
        result_list_cache = []
        field_cache = ['GWP100a', 'location']
        result_list = []
        calc_error_list = []

        if self.Calc_range_end <= len(product_system_df):
            print("maximal number of product systems: "+str(len(product_system_df)))
            if self.Calc_range_end != 0: 
                end_point = self.Calc_range_end
                start_point = self.Calc_range_start
            else:
                end_point = len(product_system_df)
                start_point = 0
            
            cached_path_csv = cached_path+"_"+str(start_point)+"_cached.csv"
            for j in range(start_point, end_point):
                key = product_system_names[j]+' | '+product_system_locations[j]+' | '+product_system_ids[j]
                print('Calculating '+key)
                try:
                    setup.product_system = client.get(olca.ProductSystem, uid=product_system_ids[j])
                    calc_result[key] = client.calculate(setup)
                    # client.excel_export(calc_result, 'calc_result/'+product_system_locations[j]+'_'+'calc_result.xlsx')
                    result = calc_result[key]
                    if result.impact_results is not None:
                        for k in range(len(result.impact_results)):
                            GWP_result = result.impact_results[k]
                            if 'GWP 100a' in GWP_result.impact_category.name:
                                GWP100a_value = GWP_result.value
                        result_list_cache.append([GWP100a_value, product_system_locations[j]])
                        result_list.append([GWP100a_value, key])
                        with open(cached_path_csv, 'w', newline="") as f:
                            write = csv.writer(f, delimiter=";")
                            write.writerow(field_cache)
                            write.writerows(result_list_cache)
                            print('Results cached.')
                    else:
                        calc_error_list.append([product_system_names[j], product_system_locations[j], product_system_ids[j]])
                        print('No impact results: '+key)
                        with open(calc_error_csv, 'w', newline="") as f:
                            write = csv.writer(f, delimiter=";")
                            write.writerows(calc_error_list)
                            print('Error results cached.')

                except Exception as e:
                    print('Failed to calculate product system: '+product_system_ids[j])
                    print("Restart OpenLCA and Jupyter kenerl and run from No."+str(j))
                    # logging.error(traceback.format_exc())
                print('Remaining number of processes to be calculated: '+str(end_point-j-1))
        else:
            print("Input ending point exceeds maximal number of product systems: "+str(len(product_system_df)))
        try:
            result_df = pd.DataFrame(result_list, columns=['GWP100a', 'key'])
            result_df[['Activity', 'Product', 'Cutoff', 'Location', 'ps_id']] = result_df.key.str.split('|', expand=True)
            result_df = result_df.drop(columns='key')
        except Exception as e:
            result_df = ''
            print('No results are written in result_df.')
            logging.error(traceback.format_exc())

        return result_df, calc_error_list
    
    def cal_from_error_list(self, calc_error_list, Created_PS_refProcess):
        setup = olca.CalculationSetup()
        setup.calculation_type = olca.CalculationType.SIMPLE_CALCULATION # TODO: Can choose SIMPLE_CALCULATION, CONTRIBUTION_ANALYSIS, UPSTREAM_ANALYSIS, REGIONALIZED_CALCULATION, MONTE_CARLO_SIMULATION
        setup.impact_method = client.find(olca.ImpactMethod, self.Impact_method)
        setup.amount = 1.0
        result_list_cache = []
        field_cache = ['GWP100a', 'location']
        cached_path_error_csv = self.Result_path + "_calc_error_cached.csv"
        for i in range(len(calc_error_list)):
            product_system_id = calc_error_list[i][2]
            product_system_location = calc_error_list[i][1]
            for key_1, value_1 in Created_PS_refProcess.items():
                for key_2, value_2 in value_1.items():
                    if key_2 == 'Product_system':
                        if value_2 == product_system_id:
                            error_process_id = key_1
            try:
                print('Recreating product system of: '+error_process_id)
                product_system = client.create_product_system(error_process_id, default_providers='prefer', preferred_type='UNIT_PROCESS') #TODO: preferred_type can be changed to "SYSTEM_PROCESS" if needed
            except Exception as e:
                print('Failed to create product system of '+error_process_id)
                logging.error(traceback.format_exc())
                print('Try to do the calculation manually in OpenLCA.')
            Created_PS_refProcess[search_process_ID]['Product_system'] = product_system.id
            try:
                setup.product_system = client.get(olca.ProductSystem, uid=product_system.id)
                print('Recalculating: '+error_process_id)
                result = client.calculate(setup)
                if result.impact_results is not None:
                    for k in range(len(result.impact_results)):
                        GWP_result = result.impact_results[k]
                        if 'GWP 100a' in GWP_result.impact_category.name:
                            GWP100a_value = GWP_result.value
                    result_list_cache.append([GWP100a_value, product_system_location])
                    with open(cached_path_error_csv, 'w', newline="") as f:
                        write = csv.writer(f, delimiter=";")
                        write.writerow(field_cache)
                        write.writerows(result_list_cache)
                        print('Results cached.')
                else:
                    print('Still no impact results: '+product_system_id)
                    print("Try to use OpenLCA client instead.")

            except Exception as e:
                print('Still no impact results: '+product_system_id)
                print("Try to use OpenLCA client instead.")

            print('Remaining number of processes to be calculated: '+str(len(calc_error_list)-i-1))

        Created_PS_refProcess_file = open("Created_PS_refProcess.json", "w")
        json.dump(Created_PS_refProcess, Created_PS_refProcess_file)
        return Created_PS_refProcess
        
    def cal_from_excel(self, Created_PS_refProcess={}):
        result_collector = []
        if len(self.Excel_path) > 0:
            material_df = pd.read_excel(self.Excel_path, header=None)
            material_df[['Activity', 'Product', 'Cutoff']] = material_df[0].str.split('|', 2, expand=True)
            material_df['Activity'] = material_df['Activity'].str.strip()

            for i in range(len(material_df)):
            # for i in range(2): # for test
                search_process_list = [Processes_df.iloc[p] for p in range(len(self.Processes_df)) if material_df['Activity'][i] in self.Processes_df.iloc[p]['name']] # search for processes with specific name
                cached_path = self.Result_path+'/Summary_'+material_df['Activity'][i]
                result_df, calc_error_list = self.create_calc_product_system(search_process_list, Created_PS_refProcess, cached_path)
                Created_PS_refProcess = self.cal_from_error_list(calc_error_list, Created_PS_refProcess)
                if len(result_df) != 0:
                    # result_df[['GWP100a', 'Location']].to_csv(self.Result_path+'/Summary_'+material_df['Activity'][i]+'.csv', index=None, sep=";")
                    print("Results are generated in given path.")
                else:
                    print('No results are written in result_df. Check log in output.')
                result_collector.append(result_df)
            return Created_PS_refProcess, result_collector
        else:
            print('Warning: Input Excel path is not valid.')
            return Created_PS_refProcess, result_collector

    def cal_from_list(self, Created_PS_refProcess={}):
        result_collector = []
        if len(self.Process_list_target) > 0:
            for i in range(len(self.Process_list_target['include'])):
                if self.Process_list_target['not_include'][i] == '':
                    search_process_list = [Processes_df.iloc[p] for p in range(len(self.Processes_df)) if self.Process_list_target['include'][i] in self.Processes_df.iloc[p]['name']] # search for processes with specific name
                else:
                    search_process_list = [Processes_df.iloc[p] for p in range(len(self.Processes_df)) if self.Process_list_target['include'][i] in self.Processes_df.iloc[p]['name'] and not self.Process_list_target['not_include'][i] in self.Processes_df.iloc[p]['name']] # search for processes with specific name
                cached_path = self.Result_path+'/Summary_'+self.Process_list_target['include'][i]
                result_df, calc_error_list = self.create_calc_product_system(search_process_list, Created_PS_refProcess, cached_path)
                Created_PS_refProcess = self.cal_from_error_list(calc_error_list, Created_PS_refProcess)
                if len(result_df) != 0:
                    print("Results are generated in given path.")
                    # result_df[['GWP100a', 'Location']].to_csv(self.Result_path+'/Summary_'+self.Process_list_target['include'][i]+'.csv', index=None, sep=";")
                else:
                    print('No results are written in result_df. Check log in output.')
                result_collector.append(result_df)
            return Created_PS_refProcess, result_collector
        else:
            print('Warning: Process list input is not valid.')
            return Created_PS_refProcess, result_collector

# %%
Impact_method = 'ei -  IPCC 2013' # TODO: change impact method as you need
# TODO: if no impact results error is found, check the impact method's name

Today = date.today().strftime("%d_%b_%Y") # day, month, year
Result_path = Today+'_GWP_100a' # TODO: change result path as you need

Excel_path = ''
# Excel_path = 'List_of_Materials_ecoinvent.xlsx' # optional, 
# TODO: if no Excel would be input, Excel_path = '', 
# otherwise, change Excel name (relative path, put the excel file under the same directory as this notebook)

# Process_list_target = ''
Process_list_target = {
    'include': ['electricity, high voltage, production mix'],  # key words you want to include
    'not_include': [''] # key words you do not want to include
} # optional, 
# TODO: if no list would be input, Process_list_target = ''
# if you want to search different activities, put your keywords accordingly in the second, third, ... position 
# in the list and remember to include an empty element '' when there's no 'not_include' keyword.

Created_PS_refProcess = json.load(open("Created_PS_refProcess.json", "r")) 
# The read json file stores the processes that are calculated and their attached product system.
# So this file should be varied from machine to machine. If there're no product systems created before in 
# your OpenLCA database, the json file should contain an empty dictionary.

Calc_range_start = 80 # TODO: start point of product system to be calculated, change as needed.
Calc_range_end = 205 # TODO: end point of product system to be calculated, change as needed
instance1 = LCA_Calculation(Processes_df, Impact_method, Result_path, Calc_range_start=Calc_range_start, Calc_range_end=Calc_range_end, Excel_path=Excel_path, Process_list_target=Process_list_target)

Created_PS_refProcess, result_collector = instance1.cal_from_excel(Created_PS_refProcess=Created_PS_refProcess) 
Created_PS_refProcess, result_collector = instance1.cal_from_list(Created_PS_refProcess=Created_PS_refProcess) 

# TODO: if you see `ERROR 500`, Failed to call method public org.openlca.ipc.RpcResponse org.openlca.ipc.handlers.Calculator.calculate(org.openlca.ipc.RpcRequest)`,
# try to increase max. memory usage in OpenLCA then restart OpenLCA and Jupyter kernel.
# Out:
# Warning: Input Excel path is not valid.
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | FI" has been created before.
# ID: 6b159a56-1dfa-4eb5-beac-37774ed0a2bf
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IN-Eastern grid" has been created before.
# ID: 2ac672c5-3e67-4352-a234-e0fa26dc8fe8
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ET" has been created before.
# ID: 494e5c07-8390-489f-b9a9-6f936df8f919
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-YN" has been created before.
# ID: 09b4ba3a-e3f3-423c-b572-a06312c4fad1
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-XJ" has been created before.
# ID: 70b37d21-2b10-4798-9a6d-77dcd463344f
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KE" has been created before.
# ID: 1cc9cdc9-e395-4811-9d59-4360792b1d17
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | DK" has been created before.
# ID: 28b9b0fc-ee10-40a6-bf5f-78c9e5f29283
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CENTREL" has been created before.
# ID: ef791bae-b9c9-4668-bb88-8649e1fb0c8d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | AL" has been created before.
# ID: e066608c-f981-4c7a-89a4-1933e7c7b59d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | JM" has been created before.
# ID: e383f3ef-ae6d-4ae7-a1eb-e03973d242ed
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BH" has been created before.
# ID: f4eb8890-125a-4a95-a786-b4ad3d4e96a7
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KW" has been created before.
# ID: 71e0ec7e-249a-445c-b3d9-a0a3f0a8f3da
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | US-MRO" has been created before.
# ID: 2da3b581-60dd-4520-ad48-8e785899ad0c
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-JX" has been created before.
# ID: f927f25e-4b36-4cfd-8d71-87e585c354fa
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-GD" has been created before.
# ID: 614a3671-e22c-4e74-bb9d-48d45372fa53
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TM" has been created before.
# ID: 5153b63c-39dd-403b-a691-48f35b59070a
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BA" has been created before.
# ID: 399a3792-2da7-4d28-83c5-445bc25abee3
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | PH" has been created before.
# ID: b5589308-9e0c-4bdb-94b6-dab80d150832
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NZ" has been created before.
# ID: 42e61f18-d7a3-487d-899d-7ccb3c8c75f8
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ME" has been created before.
# ID: c5ca6815-bbd1-4f00-8e84-891286181c13
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CM" has been created before.
# ID: 2905cce7-8795-4767-908a-265b9bf7918a
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | RS" has been created before.
# ID: 3d2286b5-4de6-46c3-82e8-9db81b9a9926
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-HB" has been created before.
# ID: 0f6ad7bc-01af-434d-b343-00f638076152
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CR" has been created before.
# ID: 54e395e6-ff7a-43ae-a30f-78be1dab958d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U |

# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | PT" has been created before.
# ID: a6a8a78f-b005-46d2-b24c-4331eacf06ec
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MX" has been created before.
# ID: 7e4f4dae-dfd1-4391-a649-249208d7a43a
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | FR" has been created before.
# ID: fa671d0d-18ea-498a-a5e3-57857d50b519
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-GZ" has been created before.
# ID: c662bb75-b3c0-4891-be14-093150f4f9e1
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-North-eastern grid" has been created before.
# ID: fbd3db8f-50e1-4ad6-9a34-6cb0b8a54fae
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | VN" has been created before.
# ID: c67411ab-ab38-4ccc-93ce-ea097b727cea
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MA" has been created before.
# ID: 2f083a90-5112-46cf-ba6e-fd3f8d375580
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NE" has been created before.
# ID: 2bb77bdf-7157-48ca-b7c8-be3ad33238ef
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TT" has been created before.
# ID: 0d5c10f9-89bc-456e-86ac-4e22bcc32e51
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NORDEL" has been created before.
# ID: 7474b487-8f6b-4339-b24b-d7018148f5ab
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NG" has been created before.
# ID: 56efa7f9-02d4-435a-80a5-ec2b2b8172a6
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MM" has been created before.
# ID: e0b75506-de62-4215-8b17-e8ed56cb11cc
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-Northern grid" has been created before.
# ID: 6d486f02-9142-454a-bdde-394686468656
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NA" has been created before.
# ID: e5a7400d-0b73-490f-b4af-bc3eb74f9b34
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ER" has been created before.
# ID: c6f4be1c-8559-43ae-b8c1-ac179d418f9d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | JP" has been created before.
# ID: ff11c7b5-9db6-43b7-9f9c-9b0ece6d1661
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SI" has been created before.
# ID: e986ba46-ff64-4e43-abb9-d9817e6197ab
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GA" has been created before.
# ID: f241cfb9-3e9a-4ed7-8a93-fe7e9d044339
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-HN" has been created before.
# ID: b8d13d7b-480d-4b7d-bf90-7f67c60922d0
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-JL" has been created before.
# ID: 85c3e328-9c8e-4a8b-a30d-4d66d323a1d2
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ES" has been created before.
# ID: b4e9e1b1-7d78-435e-9851-e5f7355cc41e
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MY" has been created before.
# ID: 4dfc843d-7908-4cff-8e4e-ecf6b2efc3d2
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GE" has been created before.
# ID: 328383ec-c8cb-431a-9317-12a22280f26e
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KP" has been created before.
# ID: a26b8578-07c0-4777-8291-6abb2f1aada9
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SE" has been created before.
# ID: 8202a263-902a-4dcd-96e1-ff13f40a8836
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-CQ" has been created before.
# ID: 8cf8dfd5-9a72-441f-9db0-370963216d0d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IN-Southern grid" has been created before.
# ID: 3dc936e7-6e2e-46ea-9f65-bf27574c2031
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ZA" has been created before.
# ID: 74be1cdf-b056-45b4-9f41-83f58089854d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BW" has been created before.
# ID: df1b44ec-6fce-4c0b-bc92-9581745441ab
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | RU" has been created before.
# ID: b20b28ed-82c3-4817-9aaf-d48be760a772
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | HU" has been created before.
# ID: d40ad9cb-ecdf-4980-8616-e52505e9cf79
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | HK" has been created before.
# ID: 5fff9f1f-5621-4852-baf4-7d9a7b5cf698
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-Southern grid" has been created before.
# ID: c81da5f0-b85e-4f84-9150-a8cdaab63aa6
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | RO" has been created before.
# ID: 5ffd2cf3-994a-43c2-9710-069edccd02ec
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-QH" has been created before.
# ID: 9541cb42-0d6f-4cec-adb5-eea26425520e
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-NS" has been created before.
# ID: e6857240-91a6-444e-853e-31c3151d9210
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GH" has been created before.
# ID: 1e487ec8-0d30-4e1d-a19f-0247c2453904
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-AB | a528e1ed-3466-4a79-afbe-a71e937b5931
# Results cached.
# Remaining number of processes to be calculated: 124
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MU | 249123a9-994f-4a77-9db7-49eb2d28e944
# Results cached.
# Remaining number of processes to be calculated: 123
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | XK | e6a51a46-a10b-484a-b96b-4ee609d2c04f
# Results cached.
# Remaining number of processes to be calculated: 122
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-NB | fcd863e6-66b4-48af-b8eb-0809fd22cf25
# Results cached.
# Remaining number of processes to be calculated: 121
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TW | 0c636aca-fdb6-4f7a-8318-7760bcdeced0
# Results cached.
# Remaining number of processes to be calculated: 120
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-BJ | d6681605-a74a-4e71-a40a-c9a722510e06
# Results cached.
# Remaining number of processes to be calculated: 119
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | US-PR | db4d4b59-c7ac-4f16-aca7-ac0986959e06
# Results cached.
# Remaining number of processes to be calculated: 118
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IQ | 3f4ae1b9-aed3-4ea0-a02b-5940c6a995b2
# Results cached.
# Remaining number of processes to be calculated: 117
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | PK | 0e57cc57-881d-4c5f-8d29-6c5067ae9720
# Results cached.
# Remaining number of processes to be calculated: 116
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NI | f3d54158-bd77-4e41-abc5-cc7858d57586
# Results cached.
# Remaining number of processes to be calculated: 115
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MD | b95b4bb7-f5a7-4d44-a965-79fc5cf557e8
# Results cached.
# Remaining number of processes to be calculated: 114
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-SD | 667a14c3-85da-4aca-a52f-9fccf2bb37e6
# Results cached.
# Remaining number of processes to be calculated: 113
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | UZ | 8a87ca0c-7ae0-49c5-a576-73bcf8ef622a
# Results cached.
# Remaining number of processes to be calculated: 112
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | US-HICC | 639dc71e-80d6-4a2a-8587-7cc64d6f598f
# Results cached.
# Remaining number of processes to be calculated: 111
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CD | b9802657-9718-4c05-83eb-ad69d24d9a7a
# Results cached.
# Remaining number of processes to be calculated: 110
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GI | 417ea4ff-7f3b-4753-826c-7c6cad10a93e
# Results cached.
# Remaining number of processes to be calculated: 109
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CY | 0a6e7dab-9f8a-4a74-abdd-1a195d7f022a
# Results cached.
# Remaining number of processes to be calculated: 108
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | AE | b9558fee-c492-45c2-88b4-91835ab9cd42
# ERROR:root:calculation failed: -32000: Unhandled server error: null
# No impact results: electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | AE | b9558fee-c492-45c2-88b4-91835ab9cd42
# Remaining number of processes to be calculated: 107
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MZ | 03c91aae-139b-4248-8853-10d1a9a4f7b5
# Results cached.
# Remaining number of processes to be calculated: 106
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-TJ | 3e5dbae3-e5ca-49dd-adc4-67d0f1496d30
# Results cached.
# Remaining number of processes to be calculated: 105
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-South-eastern grid | 8f506f52-0dee-4dbf-ae07-f324b1ad34db
# Results cached.
# Remaining number of processes to be calculated: 104
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | US-TRE | 68f82d24-d384-4f08-80a6-7e85f08dc849
# Results cached.
# Remaining number of processes to be calculated: 103
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SV | 1597fe7d-2b5b-4c64-b3b4-939e258015e6
# Results cached.
# Remaining number of processes to be calculated: 102
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BD | 19f109a6-b9b2-43e0-8071-143e1453020f
# Results cached.
# Remaining number of processes to be calculated: 101
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IN-North-eastern grid | 186dae9c-7212-49af-8f85-b5f0bec144c1
# Results cached.
# Remaining number of processes to be calculated: 100
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TZ | 51dacf98-c3c1-4532-9a19-814da09d7159
# Results cached.
# Remaining number of processes to be calculated: 99
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-CSG | aa850975-53a7-415b-b6b6-4b5e13700558
# Results cached.
# Remaining number of processes to be calculated: 98
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-NF | fd184eef-e7ac-46a9-922b-6ee910498bfd
# Results cached.
# Remaining number of processes to be calculated: 97
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | US-WECC | befed86e-27e3-4dc3-a477-4918d77ad982
# Results cached.
# Remaining number of processes to be calculated: 96
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TJ | 9dcf2a2b-3bca-42dd-a348-697e215a4553
# Results cached.
# Remaining number of processes to be calculated: 95
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | UY | 693ff12f-d51c-45b5-8c9c-4a7773c3361e
# Results cached.
# Remaining number of processes to be calculated: 94
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BY | 84c5ee46-47fd-49c3-9d43-b7e3dd58cd14
# Results cached.
# Remaining number of processes to be calculated: 93
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | LY | 69f5749b-3107-487f-903d-88d8501a9d89
# Results cached.
# Remaining number of processes to be calculated: 92
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-LN | 18c3bdb7-5fe5-45ef-a569-0ed63e9c424c
# Results cached.
# Remaining number of processes to be calculated: 91
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | US-ASCC | 5aee7027-ca97-4cd0-ac06-fc7ed0492125
# Results cached.
# Remaining number of processes to be calculated: 90
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CI | 8c93bfec-60fc-412e-9615-be800b7a82ff
# Results cached.
# Remaining number of processes to be calculated: 89
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GT | a24c6c22-0863-4e2a-812b-cb23e154170f
# Results cached.
# Remaining number of processes to be calculated: 88
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MT | 97c2b927-15d4-4c5b-bb34-fde8dd7b571e
# Results cached.
# Remaining number of processes to be calculated: 87
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KH | 2b60bf7d-d5d3-422f-85f8-282cc83d1dbc
# Results cached.
# Remaining number of processes to be calculated: 86
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | DO | 738919de-a8b9-4620-bb69-1624989aaced
# Results cached.
# Remaining number of processes to be calculated: 85
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | LV | 35ece576-56f0-4fbe-be6d-4f62b0207bc3
# Results cached.
# Remaining number of processes to be calculated: 84
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MK | 043dba81-e617-41e2-b69a-f3e06c512153
# Results cached.
# Remaining number of processes to be calculated: 83
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | YE | 670a17d9-9327-497e-8107-2195056e9443
# Results cached.
# Remaining number of processes to be calculated: 82
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SS | 2464e111-c2fa-40ac-b9e9-0657564b738f
# Results cached.
# Remaining number of processes to be calculated: 81
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GB | ea4bfe01-1ba1-4651-ac62-6f4eb21b5f66
# Results cached.
# Remaining number of processes to be calculated: 80
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | JO | 0428f7e2-e6f6-4791-bc25-2ef51c35b5a0
# Results cached.
# Remaining number of processes to be calculated: 79
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-HA | 98cedfe1-4910-45b0-830e-c7d4d6717b9f
# Results cached.
# Remaining number of processes to be calculated: 78
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BJ | 869c5093-f845-499a-9366-02c6ab836458
# Results cached.
# Remaining number of processes to be calculated: 77
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | PA | 42ab1c05-4c3f-4517-9553-7afab27234f4
# Results cached.
# Remaining number of processes to be calculated: 76
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-AH | 7161e8ff-d1ad-46a6-b47c-28cc9b4626a9
# Results cached.
# Remaining number of processes to be calculated: 75
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TG | 339d69ed-6203-48cf-9e23-b9abebd65b86
# Results cached.
# Remaining number of processes to be calculated: 74
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-SH | 3851b127-a6df-4a33-8881-b7bff2897475
# Results cached.
# Remaining number of processes to be calculated: 73
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KR | 8c1a4542-8616-417a-bb48-1bcc2d15ff4d
# Results cached.
# Remaining number of processes to be calculated: 72
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | PT | a6a8a78f-b005-46d2-b24c-4331eacf06ec
# Results cached.
# Remaining number of processes to be calculated: 71
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MX | 7e4f4dae-dfd1-4391-a649-249208d7a43a
# Results cached.
# Remaining number of processes to be calculated: 70
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | FR | fa671d0d-18ea-498a-a5e3-57857d50b519
# Results cached.
# Remaining number of processes to be calculated: 69
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-GZ | c662bb75-b3c0-4891-be14-093150f4f9e1
# Results cached.
# Remaining number of processes to be calculated: 68
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-North-eastern grid | fbd3db8f-50e1-4ad6-9a34-6cb0b8a54fae
# Results cached.
# Remaining number of processes to be calculated: 67
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | VN | c67411ab-ab38-4ccc-93ce-ea097b727cea
# Results cached.
# Remaining number of processes to be calculated: 66
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MA | 2f083a90-5112-46cf-ba6e-fd3f8d375580
# Results cached.
# Remaining number of processes to be calculated: 65
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NE | 2bb77bdf-7157-48ca-b7c8-be3ad33238ef
# Results cached.
# Remaining number of processes to be calculated: 64
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TT | 0d5c10f9-89bc-456e-86ac-4e22bcc32e51
# Results cached.
# Remaining number of processes to be calculated: 63
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NORDEL | 7474b487-8f6b-4339-b24b-d7018148f5ab
# Results cached.
# Remaining number of processes to be calculated: 62
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NG | 56efa7f9-02d4-435a-80a5-ec2b2b8172a6
# Results cached.
# Remaining number of processes to be calculated: 61
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MM | e0b75506-de62-4215-8b17-e8ed56cb11cc
# Results cached.
# Remaining number of processes to be calculated: 60
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-Northern grid | 6d486f02-9142-454a-bdde-394686468656
# Results cached.
# Remaining number of processes to be calculated: 59
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NA | e5a7400d-0b73-490f-b4af-bc3eb74f9b34
# Results cached.
# Remaining number of processes to be calculated: 58
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ER | c6f4be1c-8559-43ae-b8c1-ac179d418f9d
# Results cached.
# Remaining number of processes to be calculated: 57
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | JP | ff11c7b5-9db6-43b7-9f9c-9b0ece6d1661
# Results cached.
# Remaining number of processes to be calculated: 56
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SI | e986ba46-ff64-4e43-abb9-d9817e6197ab
# Results cached.
# Remaining number of processes to be calculated: 55
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GA | f241cfb9-3e9a-4ed7-8a93-fe7e9d044339
# Results cached.
# Remaining number of processes to be calculated: 54
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-HN | b8d13d7b-480d-4b7d-bf90-7f67c60922d0
# Results cached.
# Remaining number of processes to be calculated: 53
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-JL | 85c3e328-9c8e-4a8b-a30d-4d66d323a1d2
# Results cached.
# Remaining number of processes to be calculated: 52
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ES | b4e9e1b1-7d78-435e-9851-e5f7355cc41e
# Results cached.
# Remaining number of processes to be calculated: 51
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MY | 4dfc843d-7908-4cff-8e4e-ecf6b2efc3d2
# Results cached.
# Remaining number of processes to be calculated: 50
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GE | 328383ec-c8cb-431a-9317-12a22280f26e
# Results cached.
# Remaining number of processes to be calculated: 49
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KP | a26b8578-07c0-4777-8291-6abb2f1aada9
# Results cached.
# Remaining number of processes to be calculated: 48
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SE | 8202a263-902a-4dcd-96e1-ff13f40a8836
# Results cached.
# Remaining number of processes to be calculated: 47
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-CQ | 8cf8dfd5-9a72-441f-9db0-370963216d0d
# Results cached.
# Remaining number of processes to be calculated: 46
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IN-Southern grid | 3dc936e7-6e2e-46ea-9f65-bf27574c2031
# Results cached.
# Remaining number of processes to be calculated: 45
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ZA | 74be1cdf-b056-45b4-9f41-83f58089854d
# Results cached.
# Remaining number of processes to be calculated: 44
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BW | df1b44ec-6fce-4c0b-bc92-9581745441ab
# Results cached.
# Remaining number of processes to be calculated: 43
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | RU | b20b28ed-82c3-4817-9aaf-d48be760a772
# Results cached.
# Remaining number of processes to be calculated: 42
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | HU | d40ad9cb-ecdf-4980-8616-e52505e9cf79
# Results cached.
# Remaining number of processes to be calculated: 41
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | HK | 5fff9f1f-5621-4852-baf4-7d9a7b5cf698
# Results cached.
# Remaining number of processes to be calculated: 40
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-Southern grid | c81da5f0-b85e-4f84-9150-a8cdaab63aa6
# Results cached.
# Remaining number of processes to be calculated: 39
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | RO | 5ffd2cf3-994a-43c2-9710-069edccd02ec
# Results cached.
# Remaining number of processes to be calculated: 38
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-QH | 9541cb42-0d6f-4cec-adb5-eea26425520e
# Results cached.
# Remaining number of processes to be calculated: 37
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-NS | e6857240-91a6-444e-853e-31c3151d9210
# Results cached.
# Remaining number of processes to be calculated: 36
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GH | 1e487ec8-0d30-4e1d-a19f-0247c2453904
# Results cached.
# Remaining number of processes to be calculated: 35
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-JS | 30a20b4e-c9e9-443f-908b-ffa76bea2422
# Results cached.
# Remaining number of processes to be calculated: 34
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-ON | 4de95e57-a852-4699-b35b-4211636799aa
# Results cached.
# Remaining number of processes to be calculated: 33
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BG | f885500e-3c86-4ffd-baf4-e2ae9475bdd3
# Results cached.
# Remaining number of processes to be calculated: 32
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | US-SERC | d93d1d7b-a64d-47d3-8783-7243305e49f3
# Results cached.
# Remaining number of processes to be calculated: 31
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | DE | 9502fcd9-85fc-4e2b-87fa-06f71265a2ee
# Results cached.
# Remaining number of processes to be calculated: 30
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-Mid-western grid | 63a2ce56-7909-44c5-8a65-4d4a79f9a168
# Results cached.
# Remaining number of processes to be calculated: 29
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | AZ | 55ed1b7b-53b8-4405-a834-88eb62775ef8
# Results cached.
# Remaining number of processes to be calculated: 28
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SA | adec4422-9679-44af-8b76-76634b23b7fb
# Results cached.
# Remaining number of processes to be calculated: 27
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-SA | a29b1871-b089-4201-96f2-cdbb7f375a7a
# Results cached.
# Remaining number of processes to be calculated: 26
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IN-Western grid | da7073d6-9892-45a9-bb57-07991127001a
# Results cached.
# Remaining number of processes to be calculated: 25
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NP | 83cc3a13-0a63-44cf-927c-cefb33ac7f4d
# Results cached.
# Remaining number of processes to be calculated: 24
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CW | 8fe4fd7c-aff8-4774-80d4-13635c7d4230
# Results cached.
# Remaining number of processes to be calculated: 23
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BN | 9c9ce3f8-7c49-4330-bf56-3ebe90e7ec18
# Results cached.
# Remaining number of processes to be calculated: 22
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | HT | 8c306c12-324a-47c4-90cf-034aab6b1cdc
# Results cached.
# Remaining number of processes to be calculated: 21
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-SC | b15d0548-0529-45ce-8a9d-1c707a2c9432
# Results cached.
# Remaining number of processes to be calculated: 20
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-GS | 28784fc3-c9c9-4f11-b0eb-a6afa2cdb441
# Results cached.
# Remaining number of processes to be calculated: 19
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | UA | 2abbba2f-67d8-4247-96e9-8749b9e69dac
# Results cached.
# Remaining number of processes to be calculated: 18
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | OM | e2c1fbac-8ba8-498e-8ff6-4e27455a4124
# Results cached.
# Remaining number of processes to be calculated: 17
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | DZ | 01e30e60-e439-48ee-ad02-c12c76f28adf
# Results cached.
# Remaining number of processes to be calculated: 16
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | AO | ffc3909e-8f1a-430f-8a67-ab1fc816159e
# Results cached.
# Remaining number of processes to be calculated: 15
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NL | a49a348f-ecef-4d60-ae99-127fc090b776
# Results cached.
# Remaining number of processes to be calculated: 14
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TR | 76d9c713-dcdf-4ca9-87ff-c4786750bd82
# Results cached.
# Remaining number of processes to be calculated: 13
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KG | a7648ed0-cf3a-480b-9cc6-45d9e3a4b317
# Results cached.
# Remaining number of processes to be calculated: 12
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IN-Northern grid | 967b0c84-d97c-44ac-a1b3-7555cfd45b94
# Results cached.
# Remaining number of processes to be calculated: 11
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | EG | a1d771a1-63e3-4c67-a64e-bb3fb3ff8bdd
# Results cached.
# Remaining number of processes to be calculated: 10
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CU | 1a934b4f-680b-4aeb-8e3d-e7824a29bdaf
# Results cached.
# Remaining number of processes to be calculated: 9
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SY | 2e4dfc2d-0a03-48ef-8a9b-48349880ac9f
# Results cached.
# Remaining number of processes to be calculated: 8
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | QA | 341d9e7e-9507-4c12-966c-7bccac3a27b2
# Results cached.
# Remaining number of processes to be calculated: 7
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CH | d66a6295-8b38-4c43-b274-5610e3b03e35
# Results cached.
# Remaining number of processes to be calculated: 6
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CZ | d3009c95-52ec-4335-938e-47c1831d8042
# Results cached.
# Remaining number of processes to be calculated: 5
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-XZ | 0b244bbf-f67d-499e-9568-3936008aaa06
# Results cached.
# Remaining number of processes to be calculated: 4
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-SX | c5c23e32-770b-496a-9da9-d1ca1acff425
# Results cached.
# Remaining number of processes to be calculated: 3
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CG | 98b73ec2-e4f6-43db-b71f-dcfcb14bbdfe
# Results cached.
# Remaining number of processes to be calculated: 2
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-QC | 924dd4ac-6393-4a66-8afd-8e6dcfcc9860
# Results cached.
# Remaining number of processes to be calculated: 1
# Calculating electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-NT | 288c9529-b895-407c-9c3c-4b963a909f2d
# Results cached.
# Remaining number of processes to be calculated: 0
# Results are generated in given path.

# %%
test_json = json.load(open("Created_PS_refProcess.json", "r"))

# %%
test_json['781912de-560e-3ad7-9783-6cc9f5b9878f']
# Out:
# {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#   'FI',
#   '781912de-560e-3ad7-9783-6cc9f5b9878f'],
#  'Product_system': '6b159a56-1dfa-4eb5-beac-37774ed0a2bf'}

# %%
for key_1, value_1 in test_json.items():
    for key_2, value_2 in value_1.items():
        if key_2 == 'Product_system':
            if value_2 == product_system_id:
                print(key_1)
# Out:
# 781912de-560e-3ad7-9783-6cc9f5b9878f

# %%
def get_key(val):
    for key, value in test_json.items():
         if val == value:
             return key
 
    return "key doesn't exist"

# Driver Code
 
my_dict ={"java":100, "python":112, "c":11}
 
print(get_key(100))
print(get_key(11))
# Out:
# {'781912de-560e-3ad7-9783-6cc9f5b9878f': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'FI',
#    '781912de-560e-3ad7-9783-6cc9f5b9878f'],
#   'Product_system': '6b159a56-1dfa-4eb5-beac-37774ed0a2bf'},
#  'd35f93c0-c892-35fb-b0ba-570564253b93': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'IN-Eastern grid',
#    'd35f93c0-c892-35fb-b0ba-570564253b93'],
#   'Product_system': '2ac672c5-3e67-4352-a234-e0fa26dc8fe8'},
#  '01d250a6-4e98-467e-9251-b2d6f6e105f5': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'ET',
#    '01d250a6-4e98-467e-9251-b2d6f6e105f5'],
#   'Product_system': '494e5c07-8390-489f-b9a9-6f936df8f919'},
#  '6341dbd7-3538-316e-873c-acb717e9ba12': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-YN',
#    '6341dbd7-3538-316e-873c-acb717e9ba12'],
#   'Product_system': '09b4ba3a-e3f3-423c-b572-a06312c4fad1'},
#  '65cd3423-769f-3e21-8866-2333f283f0f1': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-XJ',
#    '65cd3423-769f-3e21-8866-2333f283f0f1'],
#   'Product_system': '70b37d21-2b10-4798-9a6d-77dcd463344f'},
#  'cd914453-a4de-45bb-96c3-47cde590bafd': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'KE',
#    'cd914453-a4de-45bb-96c3-47cde590bafd'],
#   'Product_system': '1cc9cdc9-e395-4811-9d59-4360792b1d17'},
#  '866c79e9-0c8d-377c-ad10-13be6e98c838': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'DK',
#    '866c79e9-0c8d-377c-ad10-13be6e98c838'],
#   'Product_system': '28b9b0fc-ee10-40a6-bf5f-78c9e5f29283'},
#  'ba08221f-c343-3a00-ab4e-8102447b3c90': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CENTREL',
#    'ba08221f-c343-3a00-ab4e-8102447b3c90'],
#   'Product_system': 'ef791bae-b9c9-4668-bb88-8649e1fb0c8d'},
#  '5302f1b3-1153-4be3-81ac-099857af8c15': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'AL',
#    '5302f1b3-1153-4be3-81ac-099857af8c15'],
#   'Product_system': 'e066608c-f981-4c7a-89a4-1933e7c7b59d'},
#  '7af249c6-2ea7-4c44-9b37-1c75672909b7': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'JM',
#    '7af249c6-2ea7-4c44-9b37-1c75672909b7'],
#   'Product_system': 'e383f3ef-ae6d-4ae7-a1eb-e03973d242ed'},
#  'a7eabc4a-0415-4ac1-ba0e-6995b56079da': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BH',
#    'a7eabc4a-0415-4ac1-ba0e-6995b56079da'],
#   'Product_system': 'f4eb8890-125a-4a95-a786-b4ad3d4e96a7'},
#  'fcf49e1d-1645-453c-bfb4-c70bd687800d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'KW',
#    'fcf49e1d-1645-453c-bfb4-c70bd687800d'],
#   'Product_system': '71e0ec7e-249a-445c-b3d9-a0a3f0a8f3da'},
#  '42e2dfeb-b105-36b2-bdb9-64b88243125d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'US-MRO',
#    '42e2dfeb-b105-36b2-bdb9-64b88243125d'],
#   'Product_system': '2da3b581-60dd-4520-ad48-8e785899ad0c'},
#  '7475de69-f1a4-3917-91bd-d1afca79c7aa': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-JX',
#    '7475de69-f1a4-3917-91bd-d1afca79c7aa'],
#   'Product_system': 'f927f25e-4b36-4cfd-8d71-87e585c354fa'},
#  '8b2c0b20-c7c0-34d4-9238-1eb44631843a': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-GD',
#    '8b2c0b20-c7c0-34d4-9238-1eb44631843a'],
#   'Product_system': '614a3671-e22c-4e74-bb9d-48d45372fa53'},
#  '9200391e-7721-4030-b4e8-c592c0855708': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'TM',
#    '9200391e-7721-4030-b4e8-c592c0855708'],
#   'Product_system': '5153b63c-39dd-403b-a691-48f35b59070a'},
#  'ed4a8481-8b7e-32b8-a117-386c77f4b790': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BA',
#    'ed4a8481-8b7e-32b8-a117-386c77f4b790'],
#   'Product_system': '399a3792-2da7-4d28-83c5-445bc25abee3'},
#  '200b4460-e98e-4ce4-ad2a-13812a0e44b3': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'PH',
#    '200b4460-e98e-4ce4-ad2a-13812a0e44b3'],
#   'Product_system': 'b5589308-9e0c-4bdb-94b6-dab80d150832'},
#  '868e2393-bf43-499d-a80d-da682303169d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'NZ',
#    '868e2393-bf43-499d-a80d-da682303169d'],
#   'Product_system': '42e61f18-d7a3-487d-899d-7ccb3c8c75f8'},
#  '5da66b5d-dae6-40f3-8d7c-fe2c8d7e7a98': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'ME',
#    '5da66b5d-dae6-40f3-8d7c-fe2c8d7e7a98'],
#   'Product_system': 'c5ca6815-bbd1-4f00-8e84-891286181c13'},
#  '7d36d0ea-9eb9-4f1d-9be3-f6318b1ea0c7': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CM',
#    '7d36d0ea-9eb9-4f1d-9be3-f6318b1ea0c7'],
#   'Product_system': '2905cce7-8795-4767-908a-265b9bf7918a'},
#  '7912258c-bd0a-36e3-86c9-b6f1e4c769b3': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'RS',
#    '7912258c-bd0a-36e3-86c9-b6f1e4c769b3'],
#   'Product_system': '3d2286b5-4de6-46c3-82e8-9db81b9a9926'},
#  'f46a5878-87cb-3621-aa24-adb75fce0451': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-HB',
#    'f46a5878-87cb-3621-aa24-adb75fce0451'],
#   'Product_system': '0f6ad7bc-01af-434d-b343-00f638076152'},
#  '6320f2c6-518f-4ac1-9bc7-c1685b10fb70': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CR',
#    '6320f2c6-518f-4ac1-9bc7-c1685b10fb70'],
#   'Product_system': '54e395e6-ff7a-43ae-a30f-78be1dab958d'},
#  'aa3b8c17-efd7-4d29-a77c-d536947320f7': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'AR',
#    'aa3b8c17-efd7-4d29-a77c-d536947320f7'],
#   'Product_system': '86db570c-d5b9-4dfe-a0a8-36abfc1032e8'},
#  'aa649b48-e1ff-3dd4-905f-c4c06c9deac9': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'NO',
#    'aa649b48-e1ff-3dd4-905f-c4c06c9deac9'],
#   'Product_system': 'b5a01bf9-354f-48be-8f74-b7f53b12ddde'},
#  '66550861-658b-49c4-9b5c-553d5fd21891': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'LK',
#    '66550861-658b-49c4-9b5c-553d5fd21891'],
#   'Product_system': 'cb223d3a-3bf8-4a19-b652-bb82fa448d5e'},
#  'eb80ffa7-ca3f-49b5-b043-a3c18e72030e': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'SD',
#    'eb80ffa7-ca3f-49b5-b043-a3c18e72030e'],
#   'Product_system': '6c1d1d43-661b-48c3-bd5f-48d272e9c8e3'},
#  'acd56cfa-9609-49c6-adf0-18113eeafa62': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'KZ',
#    'acd56cfa-9609-49c6-adf0-18113eeafa62'],
#   'Product_system': 'c77b37fc-1c01-4bc3-8ad0-4340966be356'},
#  '3a962edf-e463-38a1-b4b7-831267bab3f5': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'IS',
#    '3a962edf-e463-38a1-b4b7-831267bab3f5'],
#   'Product_system': '6ae5cef7-6c66-415f-ab0b-0acb85a092ac'},
#  'cccd7fd4-c107-36ae-affd-8624c50c197e': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-MB',
#    'cccd7fd4-c107-36ae-affd-8624c50c197e'],
#   'Product_system': 'c5171703-cdd3-47e8-9266-64cae848a544'},
#  'd6e6cd57-f68a-3605-8dbc-1828cc1e2675': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-PE',
#    'd6e6cd57-f68a-3605-8dbc-1828cc1e2675'],
#   'Product_system': '14e00b70-f980-41d2-a60b-a5d58768eab6'},
#  'a293fe93-267c-4b18-bf94-04091b4b77cf': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CO',
#    'a293fe93-267c-4b18-bf94-04091b4b77cf'],
#   'Product_system': 'b25fbeb0-7d0f-4151-a160-d29fc7d38337'},
#  '0325dd98-db05-354c-b988-25e4f952cb02': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-SGCC',
#    '0325dd98-db05-354c-b988-25e4f952cb02'],
#   'Product_system': '88fb0646-24fc-42ff-8744-afac1c2e69cb'},
#  'f5740edd-ac9a-3fc1-bb16-eee13d7e0cb7': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'ID',
#    'f5740edd-ac9a-3fc1-bb16-eee13d7e0cb7'],
#   'Product_system': '78895f9e-bd66-4d8e-ad22-5dc30c653210'},
#  'ef9fe5e7-3962-4d8f-aead-7500f93786c3': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'SN',
#    'ef9fe5e7-3962-4d8f-aead-7500f93786c3'],
#   'Product_system': '056df897-7f83-445e-bb14-ab68e05bd99b'},
#  '363c3b08-c932-48fd-ae78-30e1c4fee7ff': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'HN',
#    '363c3b08-c932-48fd-ae78-30e1c4fee7ff'],
#   'Product_system': '42d46986-a7ac-4911-80ae-29094a3eb5cb'},
#  '83964928-06d8-421e-8a60-cf8e316117f9': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'AM',
#    '83964928-06d8-421e-8a60-cf8e316117f9'],
#   'Product_system': '9007a74e-63d1-4413-885c-89bd0d8d94d9'},
#  'c89b43b9-7283-3e2a-bcd2-a8e17a75d452': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-NU',
#    'c89b43b9-7283-3e2a-bcd2-a8e17a75d452'],
#   'Product_system': 'fd8d05c9-5335-428c-857e-46452ba61e91'},
#  'dc471d17-b5e5-331d-a248-c9c82c5e2752': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-HL',
#    'dc471d17-b5e5-331d-a248-c9c82c5e2752'],
#   'Product_system': 'b29f0950-c288-4afa-887b-2c08ef8649b6'},
#  'ec51bb0d-48af-3bf9-8dbe-2ca8a657341f': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BR',
#    'ec51bb0d-48af-3bf9-8dbe-2ca8a657341f'],
#   'Product_system': 'a16b8f1a-a90c-4bbb-a081-1e67b698f6f0'},
#  '8ec2d93a-b7d4-35d1-9059-a29e4f93b720': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'TH',
#    '8ec2d93a-b7d4-35d1-9059-a29e4f93b720'],
#   'Product_system': '47cfb9da-fbf5-43f0-a0de-2edaf00d8565'},
#  'd4c0fb40-c18e-365b-b1f3-326bf8b0bec3': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-BC',
#    'd4c0fb40-c18e-365b-b1f3-326bf8b0bec3'],
#   'Product_system': 'eba00366-6820-4321-b44e-98baf29b90e2'},
#  '0870616a-6b0d-3a27-aea7-9f4662412953': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'LT',
#    '0870616a-6b0d-3a27-aea7-9f4662412953'],
#   'Product_system': 'b6e38d99-0415-4a15-a62a-c50bb9dea3a3'},
#  '9e9e785d-fa84-34a0-8e2d-c43d37166a8e': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-SK',
#    '9e9e785d-fa84-34a0-8e2d-c43d37166a8e'],
#   'Product_system': 'a3eef604-43ce-4e8f-bd54-6f56d7aae479'},
#  'c8b34f3a-cf4f-370b-8ef4-17702eed4fb5': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-HU',
#    'c8b34f3a-cf4f-370b-8ef4-17702eed4fb5'],
#   'Product_system': '7a223b98-fa4a-42eb-a79b-60fa6380490f'},
#  '93a88f71-c8b5-437e-894d-e800a7f4e26d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'PY',
#    '93a88f71-c8b5-437e-894d-e800a7f4e26d'],
#   'Product_system': 'fffee35c-9e60-4f2a-a404-09e3f244d039'},
#  '1d3a4b99-50d6-3c30-9ece-7c10d2c3d938': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'AU',
#    '1d3a4b99-50d6-3c30-9ece-7c10d2c3d938'],
#   'Product_system': '4ce2ea53-6420-4dd8-bcef-64cbcf6d25ec'},
#  '15c60f45-e2db-4562-8b04-dc1899f6b0c6': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'MN',
#    '15c60f45-e2db-4562-8b04-dc1899f6b0c6'],
#   'Product_system': '2f496d15-6499-4909-995d-8f246a055c0e'},
#  'e518c955-ffaa-3c62-9b83-66ff8bf62a74': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'US-NPCC',
#    'e518c955-ffaa-3c62-9b83-66ff8bf62a74'],
#   'Product_system': '1541bd27-3675-4ca8-94f9-df3a655bc89c'},
#  '08c9a812-c491-3edb-a5b3-a6f1d648f11e': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'EE',
#    '08c9a812-c491-3edb-a5b3-a6f1d648f11e'],
#   'Product_system': 'd74bff4a-d523-4552-95c3-91bfff6a7587'},
#  'ea4bac7e-7955-3cfa-b839-3fee2fcc7c6d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'US-RFC',
#    'ea4bac7e-7955-3cfa-b839-3fee2fcc7c6d'],
#   'Product_system': 'b5a00e3d-9784-4dce-ab03-a2448c8a74cd'},
#  'b66f83e0-64ff-3a9a-8f14-a3404828e100': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-GX',
#    'b66f83e0-64ff-3a9a-8f14-a3404828e100'],
#   'Product_system': '72d0857d-e408-42c8-b86a-7737aa81985c'},
#  'f56f0b54-d158-3737-a511-badd711defab': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'IE',
#    'f56f0b54-d158-3737-a511-badd711defab'],
#   'Product_system': '8f709b1a-173f-4b9a-b295-9eb9621c6760'},
#  'cf7e321a-81c4-373a-ae0c-7cd8f4a0cfca': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-ZJ',
#    'cf7e321a-81c4-373a-ae0c-7cd8f4a0cfca'],
#   'Product_system': '2e02b6d7-4e6e-4f4a-86a9-9fceb3e397d6'},
#  '66798de5-d173-39cf-8254-96423ebb5dab': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-FJ',
#    '66798de5-d173-39cf-8254-96423ebb5dab'],
#   'Product_system': '55dbb30e-08e7-468c-98bf-e75ed06835cc'},
#  'a836f281-3959-3171-b147-273fd1c904bf': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'HR',
#    'a836f281-3959-3171-b147-273fd1c904bf'],
#   'Product_system': 'bb05484f-1129-452f-b988-2448f4567132'},
#  '32ec5bbc-d08c-3f43-a94b-481bc90c8a63': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-NX',
#    '32ec5bbc-d08c-3f43-a94b-481bc90c8a63'],
#   'Product_system': 'e215b638-5117-44f7-ac29-ff23f2c1da3b'},
#  'ce2b8d7e-8ea8-45c7-924d-ca0eb9df8649': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'SG',
#    'ce2b8d7e-8ea8-45c7-924d-ca0eb9df8649'],
#   'Product_system': '52881749-f01e-4cff-829c-4c0fc3e284ac'},
#  '0943dcfe-1014-3e65-bc23-85347a7020ac': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CL',
#    '0943dcfe-1014-3e65-bc23-85347a7020ac'],
#   'Product_system': 'a82a2d4d-1020-4b6b-921b-e75199766d5b'},
#  'c4d33062-e3be-3f9b-9d43-831ba655a5c1': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'AT',
#    'c4d33062-e3be-3f9b-9d43-831ba655a5c1'],
#   'Product_system': '113c3753-8a7d-4428-b556-da7397d710dd'},
#  'c5989e85-2d2a-300f-a0ed-34e0ed5ff2e5': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'PE',
#    'c5989e85-2d2a-300f-a0ed-34e0ed5ff2e5'],
#   'Product_system': '8c5bea79-48b1-4ba6-9302-e563d025dd7a'},
#  '2b742b92-d2ec-3ba4-90e7-53aeff28d9ac': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'GR',
#    '2b742b92-d2ec-3ba4-90e7-53aeff28d9ac'],
#   'Product_system': '161a1496-d4d5-4022-a4de-1027e7f7d038'},
#  '91471ea4-d50c-3cf6-8d6a-7909617b1a28': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-HE',
#    '91471ea4-d50c-3cf6-8d6a-7909617b1a28'],
#   'Product_system': 'a9595ea6-6e52-4b0b-9543-a311fbe06d0f'},
#  '6f69366f-e42c-4e2b-9784-e19809f46eaa': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'ZW',
#    '6f69366f-e42c-4e2b-9784-e19809f46eaa'],
#   'Product_system': '0e1b44b6-eaaf-43d6-a7d1-2dae249cf2d9'},
#  '84fa8d5e-026b-4e69-b856-03bfd7f6c5ca': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'TN',
#    '84fa8d5e-026b-4e69-b856-03bfd7f6c5ca'],
#   'Product_system': '4a6147b6-b0a1-4f36-9c7d-12d3c8bfeb65'},
#  '06091602-8c95-4f24-ab68-473f01ae830a': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'ZM',
#    '06091602-8c95-4f24-ab68-473f01ae830a'],
#   'Product_system': '4dc34e82-38f0-4f07-be1d-b4d776b2d625'},
#  '997f9e1d-cbad-4301-809f-970de2c97489': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'VE',
#    '997f9e1d-cbad-4301-809f-970de2c97489'],
#   'Product_system': '1e613445-c71a-40e6-9301-6c18c28e0764'},
#  '8438fdb4-a17d-3029-8875-13dcb9930e2a': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'IT',
#    '8438fdb4-a17d-3029-8875-13dcb9930e2a'],
#   'Product_system': 'e988fd93-14ef-4d90-baaa-354d5892d187'},
#  'd51453f3-9f2f-36e6-9671-e1750b46888f': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'PL',
#    'd51453f3-9f2f-36e6-9671-e1750b46888f'],
#   'Product_system': '2da07927-c45c-4b05-bb01-b98a5c751d7e'},
#  '31c7017d-fea5-3190-8e68-eb02823b3cf3': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BE',
#    '31c7017d-fea5-3190-8e68-eb02823b3cf3'],
#   'Product_system': '4f2aef13-26de-48b4-a660-3139333073d9'},
#  '81d08833-4dd5-47ab-aa00-9e1a7e3ae948': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'EC',
#    '81d08833-4dd5-47ab-aa00-9e1a7e3ae948'],
#   'Product_system': '07d1623f-eb21-443d-b22c-12aaef0aac65'},
#  '26f8b86a-2c9d-371d-b9d3-062f90e229b9': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'LU',
#    '26f8b86a-2c9d-371d-b9d3-062f90e229b9'],
#   'Product_system': '95b986eb-d78f-4f53-ba1c-0a00d1f3eb6a'},
#  'fad3093c-f1df-313f-a0ae-4386d9c837b3': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'SK',
#    'fad3093c-f1df-313f-a0ae-4386d9c837b3'],
#   'Product_system': 'ab31afa7-1902-417b-b325-b0345442b2a8'},
#  '982ea3d5-2b1e-3509-94bb-cc7698256781': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-YK',
#    '982ea3d5-2b1e-3509-94bb-cc7698256781'],
#   'Product_system': '2dc17e59-4d90-4f66-9a00-443b9ccfe007'},
#  'b4e0a9de-62d7-3e05-bda3-3f10029a3899': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'IR',
#    'b4e0a9de-62d7-3e05-bda3-3f10029a3899'],
#   'Product_system': '9bc14947-1452-4504-8c53-3a005a4abcdb'},
#  '12980240-abd1-3b68-ba21-76084a8a4819': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-NM',
#    '12980240-abd1-3b68-ba21-76084a8a4819'],
#   'Product_system': '069fbf39-720b-433f-8d02-7d6a7d9ab4a2'},
#  '22b16217-696d-40ef-8986-a9c346896782': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'LB',
#    '22b16217-696d-40ef-8986-a9c346896782'],
#   'Product_system': '20b8e9e5-e475-49ae-ac6f-85622566f9d9'},
#  '2297de15-b76b-4c0d-ae16-2d1515b1b83f': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BO',
#    '2297de15-b76b-4c0d-ae16-2d1515b1b83f'],
#   'Product_system': '1ac2ab46-3a35-4eea-bb04-2229dd11738c'},
#  '61c2bc53-f8a4-45f1-95cf-4e40a223efc4': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'IL',
#    '61c2bc53-f8a4-45f1-95cf-4e40a223efc4'],
#   'Product_system': '22736017-c511-48b8-aa15-21afb0878110'},
#  '3da35c3f-2e7a-3f4f-bb99-75ceddbc1f5b': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-AB',
#    '3da35c3f-2e7a-3f4f-bb99-75ceddbc1f5b'],
#   'Product_system': 'a528e1ed-3466-4a79-afbe-a71e937b5931'},
#  '930d6eb1-b5af-4263-aef3-9c7411fa8455': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'MU',
#    '930d6eb1-b5af-4263-aef3-9c7411fa8455'],
#   'Product_system': '249123a9-994f-4a77-9db7-49eb2d28e944'},
#  '9d97eaba-3e32-4b3a-aa08-de17ac42bfb7': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'XK',
#    '9d97eaba-3e32-4b3a-aa08-de17ac42bfb7'],
#   'Product_system': 'e6a51a46-a10b-484a-b96b-4ee609d2c04f'},
#  '742c3970-f303-37e7-862d-74a6915395af': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-NB',
#    '742c3970-f303-37e7-862d-74a6915395af'],
#   'Product_system': 'fcd863e6-66b4-48af-b8eb-0809fd22cf25'},
#  'e63e76a2-06b0-3b33-b6a8-752713236e9d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'TW',
#    'e63e76a2-06b0-3b33-b6a8-752713236e9d'],
#   'Product_system': '0c636aca-fdb6-4f7a-8318-7760bcdeced0'},
#  '55a90d6a-824b-3fe6-ab5d-3c5ee021f50d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-BJ',
#    '55a90d6a-824b-3fe6-ab5d-3c5ee021f50d'],
#   'Product_system': 'd6681605-a74a-4e71-a40a-c9a722510e06'},
#  '6e2120d3-96f4-46e2-89f4-1f12bcf042cb': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'US-PR',
#    '6e2120d3-96f4-46e2-89f4-1f12bcf042cb'],
#   'Product_system': 'db4d4b59-c7ac-4f16-aca7-ac0986959e06'},
#  '6b8d7f45-58e6-4647-9c37-56b48e086cd0': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'IQ',
#    '6b8d7f45-58e6-4647-9c37-56b48e086cd0'],
#   'Product_system': '3f4ae1b9-aed3-4ea0-a02b-5940c6a995b2'},
#  'e6764f17-0dde-40b0-bf9a-32ee9ad3096c': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'PK',
#    'e6764f17-0dde-40b0-bf9a-32ee9ad3096c'],
#   'Product_system': '0e57cc57-881d-4c5f-8d29-6c5067ae9720'},
#  'ab758f6b-4f40-4c94-bdf1-e3eabf4d754e': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'NI',
#    'ab758f6b-4f40-4c94-bdf1-e3eabf4d754e'],
#   'Product_system': 'f3d54158-bd77-4e41-abc5-cc7858d57586'},
#  '215b5135-d19a-4a0e-98d9-d7a786413042': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'MD',
#    '215b5135-d19a-4a0e-98d9-d7a786413042'],
#   'Product_system': 'b95b4bb7-f5a7-4d44-a965-79fc5cf557e8'},
#  '6d09283d-34c4-3939-85b7-849819c941d0': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-SD',
#    '6d09283d-34c4-3939-85b7-849819c941d0'],
#   'Product_system': '667a14c3-85da-4aca-a52f-9fccf2bb37e6'},
#  'd4322249-7518-48ed-a851-bbfd39582a81': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'UZ',
#    'd4322249-7518-48ed-a851-bbfd39582a81'],
#   'Product_system': '8a87ca0c-7ae0-49c5-a576-73bcf8ef622a'},
#  '83443321-fb65-3283-9283-b52870ff5b62': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'US-HICC',
#    '83443321-fb65-3283-9283-b52870ff5b62'],
#   'Product_system': '639dc71e-80d6-4a2a-8587-7cc64d6f598f'},
#  '32084759-4c46-418b-8acd-f80204d9b70b': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CD',
#    '32084759-4c46-418b-8acd-f80204d9b70b'],
#   'Product_system': 'b9802657-9718-4c05-83eb-ad69d24d9a7a'},
#  '3af8e548-a041-4d26-8c74-718b93fc68c8': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'GI',
#    '3af8e548-a041-4d26-8c74-718b93fc68c8'],
#   'Product_system': '417ea4ff-7f3b-4753-826c-7c6cad10a93e'},
#  '0fa513c5-84c6-39a3-89b8-b4e7ce646c05': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CY',
#    '0fa513c5-84c6-39a3-89b8-b4e7ce646c05'],
#   'Product_system': '0a6e7dab-9f8a-4a74-abdd-1a195d7f022a'},
#  '54aa798a-0cff-4f8d-8a2b-dc6cb356af3d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'AE',
#    '54aa798a-0cff-4f8d-8a2b-dc6cb356af3d'],
#   'Product_system': 'b9558fee-c492-45c2-88b4-91835ab9cd42'},
#  'adc25989-2b1d-404b-91fd-688ce7c219cc': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'MZ',
#    'adc25989-2b1d-404b-91fd-688ce7c219cc'],
#   'Product_system': '03c91aae-139b-4248-8853-10d1a9a4f7b5'},
#  '376799f5-d51e-384f-b13b-dc44d9d7c1d6': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-TJ',
#    '376799f5-d51e-384f-b13b-dc44d9d7c1d6'],
#   'Product_system': '3e5dbae3-e5ca-49dd-adc4-67d0f1496d30'},
#  '72f9e2d7-192d-4690-ab7c-0be60790f197': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BR-South-eastern grid',
#    '72f9e2d7-192d-4690-ab7c-0be60790f197'],
#   'Product_system': '8f506f52-0dee-4dbf-ae07-f324b1ad34db'},
#  'becdeb83-db53-3fca-8818-1ed18cacdba6': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'US-TRE',
#    'becdeb83-db53-3fca-8818-1ed18cacdba6'],
#   'Product_system': '68f82d24-d384-4f08-80a6-7e85f08dc849'},
#  '093c867c-cc34-4883-a62d-192b448ee603': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'SV',
#    '093c867c-cc34-4883-a62d-192b448ee603'],
#   'Product_system': '1597fe7d-2b5b-4c64-b3b4-939e258015e6'},
#  'ec83ca7d-3d26-4001-a8be-e072280b1192': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BD',
#    'ec83ca7d-3d26-4001-a8be-e072280b1192'],
#   'Product_system': '19f109a6-b9b2-43e0-8071-143e1453020f'},
#  'd9c82a45-f913-3505-9129-894b40989146': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'IN-North-eastern grid',
#    'd9c82a45-f913-3505-9129-894b40989146'],
#   'Product_system': '186dae9c-7212-49af-8f85-b5f0bec144c1'},
#  '5c35b813-b68a-37ff-8472-004b5b98ed6a': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'TZ',
#    '5c35b813-b68a-37ff-8472-004b5b98ed6a'],
#   'Product_system': '51dacf98-c3c1-4532-9a19-814da09d7159'},
#  '71096a41-71ff-33d7-88c6-62b015324b09': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-CSG',
#    '71096a41-71ff-33d7-88c6-62b015324b09'],
#   'Product_system': 'aa850975-53a7-415b-b6b6-4b5e13700558'},
#  'a1e580e4-6846-3400-9373-92bb9ad2b412': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-NF',
#    'a1e580e4-6846-3400-9373-92bb9ad2b412'],
#   'Product_system': 'fd184eef-e7ac-46a9-922b-6ee910498bfd'},
#  '56a90447-b5e6-3873-9326-1e9ff4c51acf': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'US-WECC',
#    '56a90447-b5e6-3873-9326-1e9ff4c51acf'],
#   'Product_system': 'befed86e-27e3-4dc3-a477-4918d77ad982'},
#  '33b868df-c128-4d4f-985d-04e8687c43e4': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'TJ',
#    '33b868df-c128-4d4f-985d-04e8687c43e4'],
#   'Product_system': '9dcf2a2b-3bca-42dd-a348-697e215a4553'},
#  'f28bb9ff-3959-4954-8f06-eb34875270f8': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'UY',
#    'f28bb9ff-3959-4954-8f06-eb34875270f8'],
#   'Product_system': '693ff12f-d51c-45b5-8c9c-4a7773c3361e'},
#  '3cf17a40-8919-4957-94b9-92bf39232a2d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BY',
#    '3cf17a40-8919-4957-94b9-92bf39232a2d'],
#   'Product_system': '84c5ee46-47fd-49c3-9d43-b7e3dd58cd14'},
#  '727deab1-7ed4-421f-b2d3-4fd32ecac6f9': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'LY',
#    '727deab1-7ed4-421f-b2d3-4fd32ecac6f9'],
#   'Product_system': '69f5749b-3107-487f-903d-88d8501a9d89'},
#  'ce309582-c3d2-3135-b243-d3f102d5b5bb': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-LN',
#    'ce309582-c3d2-3135-b243-d3f102d5b5bb'],
#   'Product_system': '18c3bdb7-5fe5-45ef-a569-0ed63e9c424c'},
#  '3975e7fd-bbcd-377d-ac2b-e52f8f09473f': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'US-ASCC',
#    '3975e7fd-bbcd-377d-ac2b-e52f8f09473f'],
#   'Product_system': '5aee7027-ca97-4cd0-ac06-fc7ed0492125'},
#  '6e012595-27c3-4490-8097-51fd5685c780': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CI',
#    '6e012595-27c3-4490-8097-51fd5685c780'],
#   'Product_system': '8c93bfec-60fc-412e-9615-be800b7a82ff'},
#  'a2c76570-a7e4-4e33-b967-b6cc08a3249a': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'GT',
#    'a2c76570-a7e4-4e33-b967-b6cc08a3249a'],
#   'Product_system': 'a24c6c22-0863-4e2a-812b-cb23e154170f'},
#  '82c3f6f9-44be-3077-99ea-1cfb6f628f2c': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'MT',
#    '82c3f6f9-44be-3077-99ea-1cfb6f628f2c'],
#   'Product_system': '97c2b927-15d4-4c5b-bb34-fde8dd7b571e'},
#  '430a38c3-6a00-457b-9b84-36b340b236c9': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'KH',
#    '430a38c3-6a00-457b-9b84-36b340b236c9'],
#   'Product_system': '2b60bf7d-d5d3-422f-85f8-282cc83d1dbc'},
#  'd7912f00-2d39-4513-9e0f-5c0793d5de9a': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'DO',
#    'd7912f00-2d39-4513-9e0f-5c0793d5de9a'],
#   'Product_system': '738919de-a8b9-4620-bb69-1624989aaced'},
#  '936e4282-c216-3666-b51d-578cc12f547f': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'LV',
#    '936e4282-c216-3666-b51d-578cc12f547f'],
#   'Product_system': '35ece576-56f0-4fbe-be6d-4f62b0207bc3'},
#  '9c30112e-0a8e-36b2-b38f-4a53c5443c2a': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'MK',
#    '9c30112e-0a8e-36b2-b38f-4a53c5443c2a'],
#   'Product_system': '043dba81-e617-41e2-b69a-f3e06c512153'},
#  'af5ab998-04f0-4bc3-a37e-07c4851943d5': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'YE',
#    'af5ab998-04f0-4bc3-a37e-07c4851943d5'],
#   'Product_system': '670a17d9-9327-497e-8107-2195056e9443'},
#  '81cc112a-2332-474f-93eb-56c522c2a1e8': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'SS',
#    '81cc112a-2332-474f-93eb-56c522c2a1e8'],
#   'Product_system': '2464e111-c2fa-40ac-b9e9-0657564b738f'},
#  'ca8e8495-9da3-386e-8525-dfe8a5cce735': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'GB',
#    'ca8e8495-9da3-386e-8525-dfe8a5cce735'],
#   'Product_system': 'ea4bfe01-1ba1-4651-ac62-6f4eb21b5f66'},
#  '8d6e5f22-5ec5-4e99-b224-94487b169fef': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'JO',
#    '8d6e5f22-5ec5-4e99-b224-94487b169fef'],
#   'Product_system': '0428f7e2-e6f6-4791-bc25-2ef51c35b5a0'},
#  '690a3195-68f6-3e92-acf9-0ea565425874': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-HA',
#    '690a3195-68f6-3e92-acf9-0ea565425874'],
#   'Product_system': '98cedfe1-4910-45b0-830e-c7d4d6717b9f'},
#  '9a06eab8-58ee-45f1-9be2-9bc65d3483c5': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BJ',
#    '9a06eab8-58ee-45f1-9be2-9bc65d3483c5'],
#   'Product_system': '869c5093-f845-499a-9366-02c6ab836458'},
#  'e0a056be-3692-40c8-af17-93397fed7755': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'PA',
#    'e0a056be-3692-40c8-af17-93397fed7755'],
#   'Product_system': '42ab1c05-4c3f-4517-9553-7afab27234f4'},
#  'e26acb19-8a16-3ec0-b991-54726513125e': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN
{'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'NG',
#    '19a5132c-52f6-4ee7-afc0-5a81e80e9b63'],
#   'Product_system': '56efa7f9-02d4-435a-80a5-ec2b2b8172a6'},
#  'f1cd0a17-5de4-4f21-9e10-5502350c589b': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'MM',
#    'f1cd0a17-5de4-4f21-9e10-5502350c589b'],
#   'Product_system': 'e0b75506-de62-4215-8b17-e8ed56cb11cc'},
#  '6aac802e-ffba-4314-8dff-cf84ec197235': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BR-Northern grid',
#    '6aac802e-ffba-4314-8dff-cf84ec197235'],
#   'Product_system': '6d486f02-9142-454a-bdde-394686468656'},
#  'a9a293ed-028c-48e7-aeb8-d1aa46300b54': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'NA',
#    'a9a293ed-028c-48e7-aeb8-d1aa46300b54'],
#   'Product_system': 'e5a7400d-0b73-490f-b4af-bc3eb74f9b34'},
#  '9d76e6e7-ea31-4ff3-ad28-97e96c85e37a': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'ER',
#    '9d76e6e7-ea31-4ff3-ad28-97e96c85e37a'],
#   'Product_system': 'c6f4be1c-8559-43ae-b8c1-ac179d418f9d'},
#  'dff4283a-d542-36c1-9c71-eda37edc3410': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'JP',
#    'dff4283a-d542-36c1-9c71-eda37edc3410'],
#   'Product_system': 'ff11c7b5-9db6-43b7-9f9c-9b0ece6d1661'},
#  '4a430eec-a12a-3509-abdd-ccc81ce75006': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'SI',
#    '4a430eec-a12a-3509-abdd-ccc81ce75006'],
#   'Product_system': 'e986ba46-ff64-4e43-abb9-d9817e6197ab'},
#  '525b5442-d202-4a10-99b9-080ba89a29e7': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'GA',
#    '525b5442-d202-4a10-99b9-080ba89a29e7'],
#   'Product_system': 'f241cfb9-3e9a-4ed7-8a93-fe7e9d044339'},
#  'fe250d0c-a1c9-3ebc-957d-23d573347c22': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-HN',
#    'fe250d0c-a1c9-3ebc-957d-23d573347c22'],
#   'Product_system': 'b8d13d7b-480d-4b7d-bf90-7f67c60922d0'},
#  'b8a0166a-f1c9-3f1d-901c-81440483571e': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-JL',
#    'b8a0166a-f1c9-3f1d-901c-81440483571e'],
#   'Product_system': '85c3e328-9c8e-4a8b-a30d-4d66d323a1d2'},
#  '77a8a4a8-fbf7-336b-af41-5b7582ec5e22': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'ES',
#    '77a8a4a8-fbf7-336b-af41-5b7582ec5e22'],
#   'Product_system': 'b4e9e1b1-7d78-435e-9851-e5f7355cc41e'},
#  'd23d7f8d-ba40-3074-9cab-a64cecf8681b': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'MY',
#    'd23d7f8d-ba40-3074-9cab-a64cecf8681b'],
#   'Product_system': '4dfc843d-7908-4cff-8e4e-ecf6b2efc3d2'},
#  'ac73af1e-9218-4c0b-a709-def5863a4049': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'GE',
#    'ac73af1e-9218-4c0b-a709-def5863a4049'],
#   'Product_system': '328383ec-c8cb-431a-9317-12a22280f26e'},
#  'f3cf6eca-3e67-412f-9571-215d9d0bd088': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'KP',
#    'f3cf6eca-3e67-412f-9571-215d9d0bd088'],
#   'Product_system': 'a26b8578-07c0-4777-8291-6abb2f1aada9'},
#  '95cb308d-1418-3c12-9584-8ada668365cd': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'SE',
#    '95cb308d-1418-3c12-9584-8ada668365cd'],
#   'Product_system': '8202a263-902a-4dcd-96e1-ff13f40a8836'},
#  '1a6b4e2b-481d-304b-8358-a3f93d10057c': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-CQ',
#    '1a6b4e2b-481d-304b-8358-a3f93d10057c'],
#   'Product_system': '8cf8dfd5-9a72-441f-9db0-370963216d0d'},
#  '5ff7a3e2-7833-3bd7-a32d-10d585244300': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'IN-Southern grid',
#    '5ff7a3e2-7833-3bd7-a32d-10d585244300'],
#   'Product_system': '3dc936e7-6e2e-46ea-9f65-bf27574c2031'},
#  'c4bfe44c-b7cb-3f7e-8a43-a67f870393cd': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'ZA',
#    'c4bfe44c-b7cb-3f7e-8a43-a67f870393cd'],
#   'Product_system': '74be1cdf-b056-45b4-9f41-83f58089854d'},
#  'e78ae50f-8033-41f5-8581-479502ee018f': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BW',
#    'e78ae50f-8033-41f5-8581-479502ee018f'],
#   'Product_system': 'df1b44ec-6fce-4c0b-bc92-9581745441ab'},
#  'dd29e23f-5e0b-375b-95d0-b02454bcf49b': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'RU',
#    'dd29e23f-5e0b-375b-95d0-b02454bcf49b'],
#   'Product_system': 'b20b28ed-82c3-4817-9aaf-d48be760a772'},
#  'be383330-f777-303d-a172-e9d01b1288c0': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'HU',
#    'be383330-f777-303d-a172-e9d01b1288c0'],
#   'Product_system': 'd40ad9cb-ecdf-4980-8616-e52505e9cf79'},
#  '6dae2621-e8d9-46f3-a4c1-2e93dd3d9a43': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'HK',
#    '6dae2621-e8d9-46f3-a4c1-2e93dd3d9a43'],
#   'Product_system': '5fff9f1f-5621-4852-baf4-7d9a7b5cf698'},
#  '85b8e9be-9bc9-4d0f-969e-a896bdf9ead5': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BR-Southern grid',
#    '85b8e9be-9bc9-4d0f-969e-a896bdf9ead5'],
#   'Product_system': 'c81da5f0-b85e-4f84-9150-a8cdaab63aa6'},
#  '87a8b0bc-71db-3f71-8ff2-ec47a6563b0c': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'RO',
#    '87a8b0bc-71db-3f71-8ff2-ec47a6563b0c'],
#   'Product_system': '5ffd2cf3-994a-43c2-9710-069edccd02ec'},
#  '7aa50af1-2c50-3634-acc5-a257d69bc530': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-QH',
#    '7aa50af1-2c50-3634-acc5-a257d69bc530'],
#   'Product_system': '9541cb42-0d6f-4cec-adb5-eea26425520e'},
#  '421098d1-4c72-3c4e-9f62-669aba7eabb3': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-NS',
#    '421098d1-4c72-3c4e-9f62-669aba7eabb3'],
#   'Product_system': 'e6857240-91a6-444e-853e-31c3151d9210'},
#  '784d193e-2ecf-410e-af39-06e3a74bfc10': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'GH',
#    '784d193e-2ecf-410e-af39-06e3a74bfc10'],
#   'Product_system': '1e487ec8-0d30-4e1d-a19f-0247c2453904'},
#  '9b7fddc7-33f7-36ec-8e3c-235f986177ed': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-JS',
#    '9b7fddc7-33f7-36ec-8e3c-235f986177ed'],
#   'Product_system': '30a20b4e-c9e9-443f-908b-ffa76bea2422'},
#  '4d6a3213-5d4c-369d-ada4-d2134f2d5999': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-ON',
#    '4d6a3213-5d4c-369d-ada4-d2134f2d5999'],
#   'Product_system': '4de95e57-a852-4699-b35b-4211636799aa'},
#  '1dcd945c-d90f-37b9-b330-ecc647f4c19e': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BG',
#    '1dcd945c-d90f-37b9-b330-ecc647f4c19e'],
#   'Product_system': 'f885500e-3c86-4ffd-baf4-e2ae9475bdd3'},
#  '9a134b7e-1c73-393b-b588-3f31b5f5c6ee': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'US-SERC',
#    '9a134b7e-1c73-393b-b588-3f31b5f5c6ee'],
#   'Product_system': 'd93d1d7b-a64d-47d3-8783-7243305e49f3'},
#  '2038b03e-2ac4-3196-87b3-af1234412395': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'DE',
#    '2038b03e-2ac4-3196-87b3-af1234412395'],
#   'Product_system': '9502fcd9-85fc-4e2b-87fa-06f71265a2ee'},
#  'ff2f310d-7c4a-40b2-88c4-4010dc6e546a': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BR-Mid-western grid',
#    'ff2f310d-7c4a-40b2-88c4-4010dc6e546a'],
#   'Product_system': '63a2ce56-7909-44c5-8a65-4d4a79f9a168'},
#  'e8bc5fa7-8a7a-439e-afae-1384af672e2a': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'AZ',
#    'e8bc5fa7-8a7a-439e-afae-1384af672e2a'],
#   'Product_system': '55ed1b7b-53b8-4405-a834-88eb62775ef8'},
#  '38ef4f23-02f0-3dc7-b696-76d210b66c4d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'SA',
#    '38ef4f23-02f0-3dc7-b696-76d210b66c4d'],
#   'Product_system': 'adec4422-9679-44af-8b76-76634b23b7fb'},
#  'ebb9613d-33b8-37ec-bf04-699994ade5e4': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-SA',
#    'ebb9613d-33b8-37ec-bf04-699994ade5e4'],
#   'Product_system': 'a29b1871-b089-4201-96f2-cdbb7f375a7a'},
#  'a3682243-6a08-3785-b9d4-ba4d76d095ee': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'IN-Western grid',
#    'a3682243-6a08-3785-b9d4-ba4d76d095ee'],
#   'Product_system': 'da7073d6-9892-45a9-bb57-07991127001a'},
#  '39d718b7-a427-4b28-8253-d5ee2b4090bd': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'NP',
#    '39d718b7-a427-4b28-8253-d5ee2b4090bd'],
#   'Product_system': '83cc3a13-0a63-44cf-927c-cefb33ac7f4d'},
#  'feb81e8b-8c5a-442f-9fc6-2989690cf920': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CW',
#    'feb81e8b-8c5a-442f-9fc6-2989690cf920'],
#   'Product_system': '8fe4fd7c-aff8-4774-80d4-13635c7d4230'},
#  '8d0d44c2-0bda-4b29-a42f-736fe63d5e14': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'BN',
#    '8d0d44c2-0bda-4b29-a42f-736fe63d5e14'],
#   'Product_system': '9c9ce3f8-7c49-4330-bf56-3ebe90e7ec18'},
#  'dfb78f45-181b-45c3-94f0-a5d83a575aae': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'HT',
#    'dfb78f45-181b-45c3-94f0-a5d83a575aae'],
#   'Product_system': '8c306c12-324a-47c4-90cf-034aab6b1cdc'},
#  'dc1c6a45-324e-3e60-8123-ef2aaf7e6001': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-SC',
#    'dc1c6a45-324e-3e60-8123-ef2aaf7e6001'],
#   'Product_system': 'b15d0548-0529-45ce-8a9d-1c707a2c9432'},
#  'f8597372-4356-3062-9f65-fc94f1d0ac46': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-GS',
#    'f8597372-4356-3062-9f65-fc94f1d0ac46'],
#   'Product_system': '28784fc3-c9c9-4f11-b0eb-a6afa2cdb441'},
#  'da1ce692-2595-3479-87c1-ffba482c7f15': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    
{'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-XZ',
#    '90f955b4-0824-3685-abdb-e33a328d80e5'],
#   'Product_system': '0b244bbf-f67d-499e-9568-3936008aaa06'},
#  '6d20bfa5-3ab5-33f4-ad5a-65e1a8e12b1d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CN-SX',
#    '6d20bfa5-3ab5-33f4-ad5a-65e1a8e12b1d'],
#   'Product_system': 'c5c23e32-770b-496a-9da9-d1ca1acff425'},
#  '14377cd0-c6d2-4faf-b6b4-5cbbc178051d': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CG',
#    '14377cd0-c6d2-4faf-b6b4-5cbbc178051d'],
#   'Product_system': '98b73ec2-e4f6-43db-b71f-dcfcb14bbdfe'},
#  'e611733a-ef09-3f81-8a1d-e4f7bae22b79': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-QC',
#    'e611733a-ef09-3f81-8a1d-e4f7bae22b79'],
#   'Product_system': '924dd4ac-6393-4a66-8afd-8e6dcfcc9860'},
#  '2d2f9ab2-99b3-376e-9c1a-ef820ba471d1': {'Process': ['electricity, high voltage, production mix | electricity, high voltage | Cutoff, U',
#    'CA-NT',
#    '2d2f9ab2-99b3-376e-9c1a-ef820ba471d1'],
#   'Product_system': '288c9529-b895-407c-9c3c-4b963a909f2d'}}

# %%
Impact_method = 'ei -  IPCC 2013 no LT'

# %%
setup = olca.CalculationSetup()
setup.calculation_type = olca.CalculationType.SIMPLE_CALCULATION # TODO: Can choose SIMPLE_CALCULATION, CONTRIBUTION_ANALYSIS, UPSTREAM_ANALYSIS, REGIONALIZED_CALCULATION, MONTE_CARLO_SIMULATION
setup.impact_method = client.find(olca.ImpactMethod, Impact_method)
setup.amount = 1.0
setup.product_system = client.get(olca.ProductSystem, uid="6b159a56-1dfa-4eb5-beac-37774ed0a2bf")
test_result = client.calculate(setup)
# client.excel_export(calc_result, 'calc_result/'+product_system_locations[j]+'_'+'calc_result.xlsx')

# %%
test_result.impact_results.value

# %%
test_result.impact_results[2].value

# %%
# Process_list_target = ''
Process_list_target = {
    'include': ['electricity, high voltage, production mix'],  # key words you want to include
    'not_include': [''] # key words you do not want to include
} # optional, 
Created_PS_refProcess = json.load(open("Created_PS_refProcess.json", "r")) 

for i in range(len(Process_list_target['include'])):
    if Process_list_target['not_include'][i] == '':
        search_process_list = [Processes_df.iloc[p] for p in range(len(Processes_df)) if Process_list_target['include'][i] in Processes_df.iloc[p]['name']] # search for processes with specific name
product_system_ids = []
product_system_names = []
product_system_locations = []

for j in range(len(search_process_list)):
# for j in range(2): # for test
    # Create product systems for selected processes
    search_process_ID = search_process_list[j]['id']
    search_process_name = search_process_list[j]['name']
    search_process_location = search_process_list[j]['location']
    if search_process_ID not in Created_PS_refProcess.keys():
        print('Creating product system of: '+search_process_name+' | '+search_process_location)
        try:
            product_system = client.create_product_system(search_process_ID, default_providers='prefer', preferred_type='UNIT_PROCESS') #TODO: preferred_type can be changed to "SYSTEM_PROCESS" if needed
        except Exception as e:
            print('Failed to create product system of '+search_process_ID)
            logging.error(traceback.format_exc())
        product_system_ids.append(product_system.id)
        product_system_names.append(search_process_name)
        product_system_locations.append(search_process_location)
        Created_PS_refProcess[search_process_ID] = {'Process': [search_process_name, search_process_location, search_process_ID], 'Product_system': product_system.id}
    else:
        print('Product system of '+'"'+Created_PS_refProcess[search_process_ID]['Process'][0]+' | '+Created_PS_refProcess[search_process_ID]['Process'][1]+'"'+' has been created before.')
        print('ID: '+Created_PS_refProcess[search_process_ID]['Product_system'])
        product_system_ids.append(Created_PS_refProcess[search_process_ID]['Product_system'])
        product_system_names.append(Created_PS_refProcess[search_process_ID]['Process'][0])
        product_system_locations.append(Created_PS_refProcess[search_process_ID]['Process'][1])

product_system_df = pd.DataFrame(list(zip(product_system_names, product_system_ids, product_system_locations)), 
                        columns=['name', 'id', 'location'])
# Out:
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | FI" has been created before.
# ID: 6b159a56-1dfa-4eb5-beac-37774ed0a2bf
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IN-Eastern grid" has been created before.
# ID: 2ac672c5-3e67-4352-a234-e0fa26dc8fe8
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ET" has been created before.
# ID: 494e5c07-8390-489f-b9a9-6f936df8f919
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-YN" has been created before.
# ID: 09b4ba3a-e3f3-423c-b572-a06312c4fad1
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-XJ" has been created before.
# ID: 70b37d21-2b10-4798-9a6d-77dcd463344f
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KE" has been created before.
# ID: 1cc9cdc9-e395-4811-9d59-4360792b1d17
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | DK" has been created before.
# ID: 28b9b0fc-ee10-40a6-bf5f-78c9e5f29283
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CENTREL" has been created before.
# ID: ef791bae-b9c9-4668-bb88-8649e1fb0c8d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | AL" has been created before.
# ID: e066608c-f981-4c7a-89a4-1933e7c7b59d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | JM" has been created before.
# ID: e383f3ef-ae6d-4ae7-a1eb-e03973d242ed
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BH" has been created before.
# ID: f4eb8890-125a-4a95-a786-b4ad3d4e96a7
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KW" has been created before.
# ID: 71e0ec7e-249a-445c-b3d9-a0a3f0a8f3da
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | US-MRO" has been created before.
# ID: 2da3b581-60dd-4520-ad48-8e785899ad0c
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-JX" has been created before.
# ID: f927f25e-4b36-4cfd-8d71-87e585c354fa
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-GD" has been created before.
# ID: 614a3671-e22c-4e74-bb9d-48d45372fa53
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TM" has been created before.
# ID: 5153b63c-39dd-403b-a691-48f35b59070a
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BA" has been created before.
# ID: 399a3792-2da7-4d28-83c5-445bc25abee3
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | PH" has been created before.
# ID: b5589308-9e0c-4bdb-94b6-dab80d150832
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NZ" has been created before.
# ID: 42e61f18-d7a3-487d-899d-7ccb3c8c75f8
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ME" has been created before.
# ID: c5ca6815-bbd1-4f00-8e84-891286181c13
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CM" has been created before.
# ID: 2905cce7-8795-4767-908a-265b9bf7918a
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | RS" has been created before.
# ID: 3d2286b5-4de6-46c3-82e8-9db81b9a9926
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-HB" has been created before.
# ID: 0f6ad7bc-01af-434d-b343-00f638076152
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CR" has been created before.
# ID: 54e395e6-ff7a-43ae-a30f-78be1dab958d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | AR" has been created before.
# ID: 86db570c-d5b9-4dfe-a0a8-36abfc1032e8
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NO" has been created before.
# ID: b5a01bf9-354f-48be-8f74-b7f53b12ddde
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | LK" has been created before.
# ID: cb223d3a-3bf8-4a19-b652-bb82fa448d5e
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U |
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-GZ" has been created before.
# ID: c662bb75-b3c0-4891-be14-093150f4f9e1
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-North-eastern grid" has been created before.
# ID: fbd3db8f-50e1-4ad6-9a34-6cb0b8a54fae
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | VN" has been created before.
# ID: c67411ab-ab38-4ccc-93ce-ea097b727cea
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MA" has been created before.
# ID: 2f083a90-5112-46cf-ba6e-fd3f8d375580
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NE" has been created before.
# ID: 2bb77bdf-7157-48ca-b7c8-be3ad33238ef
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TT" has been created before.
# ID: 0d5c10f9-89bc-456e-86ac-4e22bcc32e51
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NORDEL" has been created before.
# ID: 7474b487-8f6b-4339-b24b-d7018148f5ab
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NG" has been created before.
# ID: 56efa7f9-02d4-435a-80a5-ec2b2b8172a6
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MM" has been created before.
# ID: e0b75506-de62-4215-8b17-e8ed56cb11cc
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-Northern grid" has been created before.
# ID: 6d486f02-9142-454a-bdde-394686468656
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NA" has been created before.
# ID: e5a7400d-0b73-490f-b4af-bc3eb74f9b34
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ER" has been created before.
# ID: c6f4be1c-8559-43ae-b8c1-ac179d418f9d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | JP" has been created before.
# ID: ff11c7b5-9db6-43b7-9f9c-9b0ece6d1661
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SI" has been created before.
# ID: e986ba46-ff64-4e43-abb9-d9817e6197ab
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GA" has been created before.
# ID: f241cfb9-3e9a-4ed7-8a93-fe7e9d044339
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-HN" has been created before.
# ID: b8d13d7b-480d-4b7d-bf90-7f67c60922d0
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-JL" has been created before.
# ID: 85c3e328-9c8e-4a8b-a30d-4d66d323a1d2
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ES" has been created before.
# ID: b4e9e1b1-7d78-435e-9851-e5f7355cc41e
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | MY" has been created before.
# ID: 4dfc843d-7908-4cff-8e4e-ecf6b2efc3d2
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GE" has been created before.
# ID: 328383ec-c8cb-431a-9317-12a22280f26e
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KP" has been created before.
# ID: a26b8578-07c0-4777-8291-6abb2f1aada9
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SE" has been created before.
# ID: 8202a263-902a-4dcd-96e1-ff13f40a8836
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-CQ" has been created before.
# ID: 8cf8dfd5-9a72-441f-9db0-370963216d0d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IN-Southern grid" has been created before.
# ID: 3dc936e7-6e2e-46ea-9f65-bf27574c2031
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | ZA" has been created before.
# ID: 74be1cdf-b056-45b4-9f41-83f58089854d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BW" has been created before.
# ID: df1b44ec-6fce-4c0b-bc92-9581745441ab
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | RU" has been created before.
# ID: b20b28ed-82c3-4817-9aaf-d48be760a772
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | HU" has been created before.
# ID: d40ad9cb-ecdf-4980-8616-e52505e9cf79
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | HK" has been created before.
# ID: 5fff9f1f-5621-4852-baf4-7d9a7b5cf698
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-Southern grid" has been created before.
# ID: c81da5f0-b85e-4f84-9150-a8cdaab63aa6
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | RO" has been created before.
# ID: 5ffd2cf3-994a-43c2-9710-069edccd02ec
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-QH" has been created before.
# ID: 9541cb42-0d6f-4cec-adb5-eea26425520e
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-NS" has been created before.
# ID: e6857240-91a6-444e-853e-31c3151d9210
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | GH" has been created before.
# ID: 1e487ec8-0d30-4e1d-a19f-0247c2453904
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-JS" has been created before.
# ID: 30a20b4e-c9e9-443f-908b-ffa76bea2422
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-ON" has been created before.
# ID: 4de95e57-a852-4699-b35b-4211636799aa
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BG" has been created before.
# ID: f885500e-3c86-4ffd-baf4-e2ae9475bdd3
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | US-SERC" has been created before.
# ID: d93d1d7b-a64d-47d3-8783-7243305e49f3
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | DE" has been created before.
# ID: 9502fcd9-85fc-4e2b-87fa-06f71265a2ee
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BR-Mid-western grid" has been created before.
# ID: 63a2ce56-7909-44c5-8a65-4d4a79f9a168
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | AZ" has been created before.
# ID: 55ed1b7b-53b8-4405-a834-88eb62775ef8
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SA" has been created before.
# ID: adec4422-9679-44af-8b76-76634b23b7fb
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-SA" has been created before.
# ID: a29b1871-b089-4201-96f2-cdbb7f375a7a
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IN-Western grid" has been created before.
# ID: da7073d6-9892-45a9-bb57-07991127001a
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NP" has been created before.
# ID: 83cc3a13-0a63-44cf-927c-cefb33ac7f4d
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CW" has been created before.
# ID: 8fe4fd7c-aff8-4774-80d4-13635c7d4230
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | BN" has been created before.
# ID: 9c9ce3f8-7c49-4330-bf56-3ebe90e7ec18
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | HT" has been created before.
# ID: 8c306c12-324a-47c4-90cf-034aab6b1cdc
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-SC" has been created before.
# ID: b15d0548-0529-45ce-8a9d-1c707a2c9432
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-GS" has been created before.
# ID: 28784fc3-c9c9-4f11-b0eb-a6afa2cdb441
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | UA" has been created before.
# ID: 2abbba2f-67d8-4247-96e9-8749b9e69dac
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | OM" has been created before.
# ID: e2c1fbac-8ba8-498e-8ff6-4e27455a4124
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | DZ" has been created before.
# ID: 01e30e60-e439-48ee-ad02-c12c76f28adf
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | AO" has been created before.
# ID: ffc3909e-8f1a-430f-8a67-ab1fc816159e
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | NL" has been created before.
# ID: a49a348f-ecef-4d60-ae99-127fc090b776
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | TR" has been created before.
# ID: 76d9c713-dcdf-4ca9-87ff-c4786750bd82
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | KG" has been created before.
# ID: a7648ed0-cf3a-480b-9cc6-45d9e3a4b317
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | IN-Northern grid" has been created before.
# ID: 967b0c84-d97c-44ac-a1b3-7555cfd45b94
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | EG" has been created before.
# ID: a1d771a1-63e3-4c67-a64e-bb3fb3ff8bdd
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CU" has been created before.
# ID: 1a934b4f-680b-4aeb-8e3d-e7824a29bdaf
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | SY" has been created before.
# ID: 2e4dfc2d-0a03-48ef-8a9b-48349880ac9f
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | QA" has been created before.
# ID: 341d9e7e-9507-4c12-966c-7bccac3a27b2
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CH" has been created before.
# ID: d66a6295-8b38-4c43-b274-5610e3b03e35
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CZ" has been created before.
# ID: d3009c95-52ec-4335-938e-47c1831d8042
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-XZ" has been created before.
# ID: 0b244bbf-f67d-499e-9568-3936008aaa06
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CN-SX" has been created before.
# ID: c5c23e32-770b-496a-9da9-d1ca1acff425
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CG" has been created before.
# ID: 98b73ec2-e4f6-43db-b71f-dcfcb14bbdfe
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-QC" has been created before.
# ID: 924dd4ac-6393-4a66-8afd-8e6dcfcc9860
# Product system of "electricity, high voltage, production mix | electricity, high voltage | Cutoff, U | CA-NT" has been created before.
# ID: 288c9529-b895-407c-9c3c-4b963a909f2d

# %%
len(product_system_df)
# Out:
# 205

# %%
product_system_locations[80]
# Out:
# 'CA-AB'
